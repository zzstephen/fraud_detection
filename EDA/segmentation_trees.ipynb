# %%
from sklearn import tree
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv('../../../data/Base.csv')

# %%
drivers = ['credit_risk_score','name_email_similarity', 'email_is_free', 'phone_mobile_valid', 'foreign_request','keep_alive_session','has_other_cards']

# %%
raw_data1 = raw_data[['fraud_bool']+drivers].copy()

# %%
clf = tree.DecisionTreeClassifier(random_state=0, max_depth=5)

# %%
clf = clf.fit(raw_data1[drivers], raw_data1.fraud_bool)

# %%
plt.figure(figsize=(12,12))  # set plot size (denoted in inches)
tree.plot_tree(clf, feature_names = drivers, fontsize=10)
plt.show()
